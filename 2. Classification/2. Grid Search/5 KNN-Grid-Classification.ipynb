# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
print(np.__version__)
# Out:
# 1.26.4

# %%
# Reading the Dataset
dataset = pd.read_csv('Social_Network_Ads.csv')

# %%
dataset.head(133)
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 128  15722758    Male   30            17000          0
# 129  15792102  Female   26            84000          0
# 130  15675185    Male   31            58000          0
# 131  15801247    Male   33            31000          0
# 132  15725660    Male   30            87000          0
#
# [133 rows x 5 columns]

# %%
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0         True
# 1    15810944   35            20000          0         True
# 2    15668575   26            43000          0        False
# 3    15603246   27            57000          0        False
# 4    15804002   19            76000          0         True
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1        False
# 396  15706071   51            23000          1         True
# 397  15654296   50            20000          1        False
# 398  15755018   36            33000          0         True
# 399  15594041   49            36000          1        False
#
# [400 rows x 5 columns]

# %%
indep=dataset[['Age', 'EstimatedSalary','Gender_Male']]
dep=dataset['Purchased']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_= sc.fit_transform(X_train)
X_test_= sc.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'n_neighbors':[5,7,9],'weights':['uniform','distance'],
              'algorithm':['aut', 'ball_tree', 'kd_tree', 'brute',],
             'p':[1,2]} 



grid = GridSearchCV(KNeighborsClassifier(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1') 
   
# fitting the model for grid search 
grid.fit(X_train_, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 60 fits failed out of a total of 240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 24 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'algorithm' parameter of KNeighborsClassifier must be a str among {'brute', 'auto', 'ball_tree', 'kd_tree'}. Got 'aut' instead.
#
# --------------------------------------------------------------------------------
# 22 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'algorithm' parameter of KNeighborsClassifier must be a str among {'ball_tree', 'brute', 'kd_tree', 'auto'}. Got 'aut' instead.
#
# --------------------------------------------------------------------------------
# 13 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'algorithm' parameter of KNeighborsClassifier must be a str among {'ball_tree', 'kd_tree', 'auto', 'brute'}. Got 'aut' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'algorithm' parameter of KNeighborsClassifier must be a str among {'kd_tree', 'ball_tree', 'auto', 'brute'}. Got 'aut' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.8661518  0.86058619 0.87906428 0.85635214 0.8615062  0.83577258
#  0.86341097 0.85696855 0.84829353 0.85772107 0.85444738 0.86175025
#  0.8661518  0.86058619 0.87906428 0.85635214 0.8615062  0.83577258
#  0.86341097 0.85696855 0.84829353 0.85772107 0.85444738 0.86175025
#  0.8661518  0.86058619 0.87906428 0.85635214 0.8615062  0.83577258
#  0.86341097 0.85696855 0.84829353 0.85772107 0.85444738 0.86175025]
#   warnings.warn(
# GridSearchCV(estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['aut', 'ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [5, 7, 9], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              scoring='f1', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test_) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)



# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
print(grid.best_params_)
# Out:
# {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000000      0.000000         0.000000        0.000000
# 1        0.002179      0.004029         0.000000        0.000000
# 2        0.000153      0.000306         0.000000        0.000000
# 3        0.001542      0.000553         0.000000        0.000000
# 4        0.001699      0.001180         0.000000        0.000000
# 5        0.001046      0.000094         0.000000        0.000000
# 6        0.001125      0.000157         0.000000        0.000000
# 7        0.001246      0.000386         0.000000        0.000000
# 8        0.001409      0.000439         0.000000        0.000000
# 9        0.001101      0.000202         0.000000        0.000000
# 10       0.001126      0.000501         0.000000        0.000000
# 11       0.001181      0.000243         0.000000        0.000000
# 12       0.002673      0.001354         0.024095        0.007411
# 13       0.004478      0.003302         0.012598        0.004480
# 14       0.001366      0.001479         0.023944        0.001383
# 15       0.003857      0.002134         0.011031        0.001986
# 16       0.003787      0.001579         0.020873        0.002084
# 17       0.002756      0.001022         0.009428        0.000701
# 18       0.003049      0.000880         0.019834        0.000597
# 19       0.003310      0.000379         0.008432        0.000400
# 20       0.003272      0.000804         0.019325        0.001824
# 21       0.002919      0.000952         0.009879        0.001461
# 22       0.002081      0.001092         0.018038        0.002895
# 23       0.002012      0.004023         0.009488        0.001188
# 24       0.000600      0.001200         0.019236        0.002983
# 25       0.000000      0.000000         0.010070        0.000012
# 26       0.004025      0.004929         0.020677        0.007234
# 27       0.002731      0.003911         0.007029        0.003709
# 28       0.004252      0.004743         0.017554        0.005564
# 29       0.001200      0.001469         0.012165        0.004806
# 30       0.002827      0.000420         0.021248        0.001415
# 31       0.002890      0.000471         0.009050        0.000533
# 32       0.003354      0.000436         0.020579        0.001548
# 33       0.003010      0.000023         0.009001        0.001000
# 34       0.003678      0.001575         0.019986        0.001010
# 35       0.002385      0.001225         0.009120        0.000787
# 36       0.002370      0.000838         0.087153        0.095836
# 37       0.004286      0.001644         0.008632        0.000589
# 38       0.001800      0.000979         0.048990        0.081348
# 39       0.003665      0.002491         0.004839        0.003284
# 40       0.001928      0.001038         0.047160        0.080674
# 41       0.000800      0.000980         0.009851        0.000747
# 42       0.001091      0.000913         0.009079        0.000856
# 43       0.000690      0.001381         0.006073        0.004959
# 44       0.000000      0.000000         0.010953        0.001742
# 45       0.000000      0.000000         0.010961        0.001738
# 46       0.000799      0.000979         0.008391        0.002862
# 47       0.002537      0.003202         0.008307        0.002882
#
#    param_algorithm  param_n_neighbors  param_p param_weights  \
# 0              aut                  5        1       uniform
# 1              aut                  5        1      distance
# 2              aut                  5        2       uniform
# 3              aut                  5        2      distance
# 4              aut                  7        1       uniform
# 5              aut                  7        1      distance
# 6              aut                  7        2       uniform
# 7              aut                  7        2      distance
# 8              aut                  9        1       uniform
# 9              aut                  9        1      distance
# 10             aut                  9        2       uniform
# 11             aut                  9        2      distance
# 12       ball_tree                  5        1       uniform
# 13       ball_tree                  5        1      distance
# 14       ball_tree                  5        2       uniform
# 15       ball_tree                  5        2      distance
# 16       ball_tree                  7        1       uniform
# 17       ball_tree                  7        1      distance
# 18       ball_tree                  7        2       uniform
# 19       ball_tree                  7        2      distance
# 20       ball_tree                  9        1       uniform
# 21       ball_tree                  9        1      distance
# 22       ball_tree                  9        2       uniform
# 23       ball_tree                  9        2      distance
# 24         kd_tree                  5        1       uniform
# 25         kd_tree                  5        1      distance
# 26         kd_tree                  5        2       uniform
# 27         kd_tree                  5        2      distance
# 28         kd_tree                  7        1       uniform
# 29         kd_tree                  7        1      distance
# 30         kd_tree                  7        2       uniform
# 31         kd_tree                  7        2      distance
# 32         kd_tree                  9        1       uniform
# 33         kd_tree                  9        1      distance
# 34         kd_tree                  9        2       uniform
# 35         kd_tree                  9        2      distance
# 36           brute                  5        1       uniform
# 37           brute                  5        1      distance
# 38           brute                  5        2       uniform
# 39           brute                  5        2      distance
# 40           brute                  7        1       uniform
# 41           brute                  7        1      distance
# 42           brute                  7        2       uniform
# 43           brute                  7        2      distance
# 44           brute                  9        1       uniform
# 45           brute                  9        1      distance
# 46           brute                  9        2       uniform
# 47           brute                  9        2      distance
#
#                                                params  split0_test_score  \
# 0   {'algorithm': 'aut', 'n_neighbors': 5, 'p': 1,...                NaN
# 1   {'algorithm': 'aut', 'n_neighbors': 5, 'p': 1,...                NaN
# 2   {'algorithm': 'aut', 'n_neighbors': 5, 'p': 2,...                NaN
# 3   {'algorithm': 'aut', 'n_neighbors': 5, 'p': 2,...                NaN
# 4   {'algorithm': 'aut', 'n_neighbors': 7, 'p': 1,...                NaN
# 5   {'algorithm': 'aut', 'n_neighbors': 7, 'p': 1,...                NaN
# 6   {'algorithm': 'aut', 'n_neighbors': 7, 'p': 2,...                NaN
# 7   {'algorithm': 'aut', 'n_neighbors': 7, 'p': 2,...                NaN
# 8   {'algorithm': 'aut', 'n_neighbors': 9, 'p': 1,...                NaN
# 9   {'algorithm': 'aut', 'n_neighbors': 9, 'p': 1,...                NaN
# 10  {'algorithm': 'aut', 'n_neighbors': 9, 'p': 2,...                NaN
# 11  {'algorithm': 'aut', 'n_neighbors': 9, 'p': 2,...                NaN
# 12  {'algorithm': 'ball_tree', 'n_neighbors': 5, '...           0.764706
# 13  {'algorithm': 'ball_tree', 'n_neighbors': 5, '...           0.800000
# 14  {'algorithm': 'ball_tree', 'n_neighbors': 5, '...           0.800000
# 15  {'algorithm': 'ball_tree', 'n_neighbors': 5, '...           0.764706
# 16  {'algorithm': 'ball_tree', 'n_neighbors': 7, '...           0.800000
# 17  {'algorithm': 'ball_tree', 'n_neighbors': 7, '...           0.764706
# 18  {'algorithm': 'ball_tree', 'n_neighbors': 7, '...           0.800000
# 19  {'algorithm': 'ball_tree', 'n_neighbors': 7, '...           0.764706
# 20  {'algorithm': 'ball_tree', 'n_neighbors': 9, '...           0.764706
# 21  {'algorithm': 'ball_tree', 'n_neighbors': 9, '...           0.800000
# 22  {'algorithm': 'ball_tree', 'n_neighbors': 9, '...           0.764706
# 23  {'algorithm': 'ball_tree', 'n_neighbors': 9, '...           0.764706
# 24  {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p'...           0.764706
# 25  {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p'...           0.800000
# 26  {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p'...           0.800000
# 27  {'algorithm': 'kd_tree', 'n_neighbors': 5, 'p'...           0.764706
# 28  {'algorithm': 'kd_tree', 'n_neighbors': 7, 'p'...           0.800000
# 29  {'algorithm': 'kd_tree', 'n_neighbors': 7, 'p'...           0.764706
# 30  {'algorithm': 'kd_tree', 'n_neighbors': 7, 'p'...           0.800000
# 31  {'algorithm': 'kd_tree', 'n_neighbors': 7, 'p'...           0.764706
# 32  {'algorithm': 'kd_tree', 'n_neighbors': 9, 'p'...           0.764706
# 33  {'algorithm': 'kd_tree', 'n_neighbors': 9, 'p'...           0.800000
# 34  {'algorithm': 'kd_tree', 'n_neighbors': 9, 'p'...           0.764706
# 35  {'algorithm': 'kd_tree', 'n_neighbors': 9, 'p'...           0.764706
# 36  {'algorithm': 'brute', 'n_neighbors': 5, 'p': ...           0.764706
# 37  {'algorithm': 'brute', 'n_neighbors': 5, 'p': ...           0.800000
# 38  {'algorithm': 'brute', 'n_neighbors': 5, 'p': ...           0.800000
# 39  {'algorithm': 'brute', 'n_neighbors': 5, 'p': ...           0.764706
# 40  {'algorithm': 'brute', 'n_neighbors': 7, 'p': ...           0.800000
# 41  {'algorithm': 'brute', 'n_neighbors': 7, 'p': ...           0.764706
# 42  {'algorithm': 'brute', 'n_neighbors': 7, 'p': ...           0.800000
# 43  {'algorithm': 'brute', 'n_neighbors': 7, 'p': ...           0.764706
# 44  {'algorithm': 'brute', 'n_neighbors': 9, 'p': ...           0.764706
# 45  {'algorithm': 'brute', 'n_neighbors': 9, 'p': ...           0.800000
# 46  {'algorithm': 'brute', 'n_neighbors': 9, 'p': ...           0.764706
# 47  {'algorithm': 'brute', 'n_neighbors': 9, 'p': ...           0.764706
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12           0.864865           0.800000           0.926829
# 13           0.864865           0.790698           0.900000
# 14           0.864865           0.829268           0.926829
# 15           0.833333           0.809524           0.926829
# 16           0.833333           0.800000           0.926829
# 17           0.833333           0.761905           0.900000
# 18           0.833333           0.809524           0.926829
# 19           0.864865           0.809524           0.926829
# 20           0.833333           0.769231           0.926829
# 21           0.833333           0.809524           0.926829
# 22           0.833333           0.800000           0.926829
# 23           0.833333           0.809524           0.926829
# 24           0.864865           0.800000           0.926829
# 25           0.864865           0.790698           0.900000
# 26           0.864865           0.829268           0.926829
# 27           0.833333           0.809524           0.926829
# 28           0.833333           0.800000           0.926829
# 29           0.833333           0.761905           0.900000
# 30           0.833333           0.809524           0.926829
# 31           0.864865           0.809524           0.926829
# 32           0.833333           0.769231           0.926829
# 33           0.833333           0.809524           0.926829
# 34           0.833333           0.800000           0.926829
# 35           0.833333           0.809524           0.926829
# 36           0.864865           0.800000           0.926829
# 37           0.864865           0.790698           0.900000
# 38           0.864865           0.829268           0.926829
# 39           0.833333           0.809524           0.926829
# 40           0.833333           0.800000           0.926829
# 41           0.833333           0.761905           0.900000
# 42           0.833333           0.809524           0.926829
# 43           0.864865           0.809524           0.926829
# 44           0.833333           0.769231           0.926829
# 45           0.833333           0.809524           0.926829
# 46           0.833333           0.800000           0.926829
# 47           0.833333           0.809524           0.926829
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               37
# 1                 NaN              NaN             NaN               37
# 2                 NaN              NaN             NaN               37
# 3                 NaN              NaN             NaN               37
# 4                 NaN              NaN             NaN               37
# 5                 NaN              NaN             NaN               37
# 6                 NaN              NaN             NaN               37
# 7                 NaN              NaN             NaN               37
# 8                 NaN              NaN             NaN               37
# 9                 NaN              NaN             NaN               37
# 10                NaN              NaN             NaN               37
# 11                NaN              NaN             NaN               37
# 12           0.974359         0.866152        0.077536                4
# 13           0.947368         0.860586        0.059427               16
# 14           0.974359         0.879064        0.063710                1
# 15           0.947368         0.856352        0.069818               25
# 16           0.947368         0.861506        0.063244               13
# 17           0.918919         0.835773        0.065653               34
# 18           0.947368         0.863411        0.061482                7
# 19           0.918919         0.856969        0.062521               22
# 20           0.947368         0.848294        0.076740               31
# 21           0.918919         0.857721        0.054352               19
# 22           0.947368         0.854447        0.071186               28
# 23           0.974359         0.861750        0.077290               10
# 24           0.974359         0.866152        0.077536                4
# 25           0.947368         0.860586        0.059427               16
# 26           0.974359         0.879064        0.063710                1
# 27           0.947368         0.856352        0.069818               25
# 28           0.947368         0.861506        0.063244               13
# 29           0.918919         0.835773        0.065653               34
# 30           0.947368         0.863411        0.061482                7
# 31           0.918919         0.856969        0.062521               22
# 32           0.947368         0.848294        0.076740               31
# 33           0.918919         0.857721        0.054352               19
# 34           0.947368         0.854447        0.071186               28
# 35           0.974359         0.861750        0.077290               10
# 36           0.974359         0.866152        0.077536                4
# 37           0.947368         0.860586        0.059427               16
# 38           0.974359         0.879064        0.063710                1
# 39           0.947368         0.856352        0.069818               25
# 40           0.947368         0.861506        0.063244               13
# 41           0.918919         0.835773        0.065653               34
# 42           0.947368         0.863411        0.061482                7
# 43           0.918919         0.856969        0.062521               22
# 44           0.947368         0.848294        0.076740               31
# 45           0.918919         0.857721        0.054352               19
# 46           0.947368         0.854447        0.071186               28
# 47           0.974359         0.861750        0.077290               10

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'algorithm': 'ball_tree', 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}: 0.9183922682195829

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[78  7]
#  [ 4 45]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93        85
#            1       0.87      0.92      0.89        49
#
#     accuracy                           0.92       134
#    macro avg       0.91      0.92      0.91       134
# weighted avg       0.92      0.92      0.92       134

# %%
print(X_test)
# Out:
#      Age  EstimatedSalary  Gender_Male
# 132   30            87000         True
# 309   38            50000        False
# 341   35            75000         True
# 196   30            79000        False
# 246   35            50000        False
# ..   ...              ...          ...
# 168   29           148000         True
# 150   26            15000        False
# 393   60            42000         True
# 66    24            19000         True
# 240   42           149000         True
#
# [134 rows x 3 columns]

# %%
Future_Prediction=grid.predict([[51,23500,1]])
Future_Prediction
# Out:
# array([1], dtype=int64)

# %%
# age_input=float(input("Age:"))
age_input=float(input("Age:"))
salary_input=float(input("Salary:"))
gender_male_input=int(input("Sex Male 0 or 1:"))
# Out:
# Age: 51
# Salary: 23500
# Sex Male 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,salary_input,gender_male_input]])
# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1]
