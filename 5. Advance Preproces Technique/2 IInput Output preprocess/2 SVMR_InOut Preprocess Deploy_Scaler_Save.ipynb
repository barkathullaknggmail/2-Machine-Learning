# %%
import pandas as pd
import pickle

# %%
# Load Scaler
scx = pickle.load(open("input_scaler.sav", 'rb'))
scy = pickle.load(open("output_scaler.sav", 'rb'))

# %%
# Load Model
model = pickle.load(
    open("Finalized_Model_SVM_pre_process.sav", "rb")
)

# %%
# get_input=([[1234,345,4565,1,0]])
get_input=scx.transform([[1234,345,4565,1,0]])
get_input
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.46890682, -4.79078955, -1.50311337,  2.        , -0.76870611]])

# %%
# Predict Model
load_model=pickle.load(open("Finalized_Model_SVM_pre_process.sav",'rb'))
result=load_model.predict(get_input)
result
# Out:
# array([-0.05299932])

# %%
original_output=scy.inverse_transform([result])
original_output
# Out:
# array([[107945.67325288]])
